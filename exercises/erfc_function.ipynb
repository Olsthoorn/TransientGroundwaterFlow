# %% [markdown]
# # the erfc function

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as sp

# %%
u = np.linspace(0, 5, 51)
y = sp.erfc(u)

# %%
plt.title('erfc function')
plt.ylabel('erfc(u)')
plt.xlabel('u -->')
plt.grid()

plt.plot(u, y)
plt.show()
