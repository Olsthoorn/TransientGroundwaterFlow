# %% [markdown]
# # Sudden change of head at $x=0$, 1D flow in a semi-infinite aquifer
#
# IHE, Delft, 2017
#
# @T.N.Olsthoorn

# %% [markdown]
# ## Setting and analytical solution
#
# The aquifer is has semi-infinite extent, i.e. $0 \le x \le \infty$. It is considered of constant transmissivity $kD$ and constnat storage coefficient $S$.
#
# The partial differential equation that is governing the flow reads
#
# $$ kD \frac {\partial^2 s} {\partial x} = S \frac {\partial s} {\partial t}  $$
#
#
# The analytical transient solution for change of head caused by a sudden, forced, change of hat at $x=0$ and $t=0$ is equal to $A [m]$, is
#
# $$ s(x, t) = A \,\mbox{erfc}(u), \,\,\,\, u=\sqrt{\frac {x^2 S} {4 kD t}} $$
#
# Where $\mbox{erfc} () $ is the so-called complementary error function:
#
# $$ \mbox{erfc} (z) = \frac 2 {\sqrt {\pi} } \intop _z ^\infty e ^{-y^2}dy $$
#
# And so its derivative is
#
# $$ \frac {d \mbox{erfc}(z)} {d z} = - \frac 2 {\sqrt {\pi}} e ^{-z^2} $$
#
# Therefore, the discharge equals
#
# $$ Q = -kD \frac {\partial s} {\partial x} = A \sqrt{\frac {kDS} {\pi t}} \exp \left( -\frac {x^2 S} {4 kD t} \right) $$
#
# and for $ x = 0 $
#
# $$ Q_0 = A \sqrt{\frac {kD S} {\pi t}}$$

# %% [markdown]
# ## Importing modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erfc
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
from collections import Counter
from matplotlib.patches import Path, PathPatch
from matplotlib.lines import Line2D
import pdb

# %% [markdown]
# ### Convenience function for setting up a graph

# %%
def newfig(title='?', xlabel='?', ylabel='?', xlim=None, ylim=None,
                   xscale='linear', yscale='linear', size_inches=(14, 8)):
    '''Setup a new axis for plotting'''
    fig, ax = plt.subplots()
    fig.set_size_inches(size_inches)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_xscale(xscale)
    ax.set_yscale(yscale)
    if xlim is not None: ax.set_xlim(xlim)
    if ylim is not None: ax.set_ylim(ylim)
    ax.grid(True)
    return ax

attribs = lambda obj: [o for o in dir(obj) if not o.startswith('_')]

# %% [markdown]
# ## Implementation

# %%
# aquifer properties
kD = 900 # m2/d
S = 0.1 # [-]

counter = Counter()

T200 = 200 ** 2 * S / (4 * kD) # Characteristic time for x=200

A = 1.5 # m amount of sudden rise of head at x=0 and t=0

x = np.linspace(0, 1000, 501) # coordinates at which to compute the head change and discharge
times0 = np.hstack((np.array([0.01, 0.1]), np.arange(11))) * T200 # times at which to show the had and discharges as a function of x
times1 = np.linspace(0, 10, 100) * T200
times1 = np.unique(np.hstack((times0, times1)))[1:] # now includes exact times0 values

fig, axs = plt.subplots(2, 1, sharex=True)
fig.set_size_inches(12, 8)
axs[0].set_title("Effect of sudden head change at $x$=0 and $t$=0 on head(x t).")
axs[1].set_title("Effect of sudden head change at $x$=0 and $t$=0 on discharge(x t).")
axs[0].set_xlabel('x [m]')
axs[1].set_xlabel('x [m]')
axs[0].set_ylabel("Head change [m] as a function of x.")
axs[1].set_ylabel("Discharge [m2/d] as a function of x")
axs[0].grid()
axs[1].grid()

artists = []

bbox = dict(boxstyle="round", color="0.8")

colors = ['brgkmc']
cnt = Counter()
cnt['it'] = 0

def plot_all(t, update=False):
    k = 0
    u = np.sqrt((x**2 * S)/(4 * kD * t))
    s = A * erfc(u)
    Q = A * np.sqrt((kD * S)/(np.pi * t)) * np.exp(-u**2)

    if not update:
        line, = axs[0].plot(x, s)
        artists.append(line)
        k += 1
        line, = axs[1].plot(x, Q)
        artists.append(line)
        k +=1
    else:
        artists[k].set_data(x, s)
        k += 1
        artists[k].set_data(x, Q)
        k += 1
        if t in times0:
            cnt['it'] += 1
            clr = colors[cnt['it'] % len(colors)]
            axs[0].plot(x, s, label=f't = {t:8.2f} d')
            axs[1].plot(x, Q, label=f't = {t:8.2f} d')
            axs[0].legend(loc="upper right")
            axs[1].legend(loc="upper right")
    if not update:
        #axs[0].legend(loc="upper right")
        #axs[1].legend(loc="upper right")
        txt = axs[0].text(0.63, 0.81, "t = {:8.2f} d".format(t), transform=axs[0].transAxes, bbox=bbox)
        artists.append(txt)        
        txt = axs[1].text(0.63, 0.81, "t = {:8.2f} d".format(t), transform=axs[1].transAxes, bbox=bbox)
        artists.append(txt)
    else:
        artists[-2].set_text("t = {:8.2f} d".format(t))
        artists[-1].set_text("t = {:8.2f} d".format(t))

    return artists

def init():
    for line in lines:
        line.set_data([],[])
        
    return lines

def animate(t):
    return plot_all(t, update=True)

plot_all(times[0], update=False)

axs[0].text(0.27, 0.81, f"A={A:.2f} m, kD={kD:.0f} m2/d, S={S:.2f} [-]", transform=axs[0].transAxes, bbox=bbox)
axs[1].text(0.27, 0.81, f"A={A:.2f} m, kD={kD:.0f} m2/d, S={S:.2f} [-]", transform=axs[1].transAxes, bbox=bbox)

if True:
    anim = FuncAnimation(fig, animate, init_func=init,
                                       frames=times1, 
                                       fargs=None,
                                       interval=500, blit=True, repeat=False)
    print('Done!')

    plt.close(anim._fig)
    #out = HTML(anim.to_html5_video())
# Out:
# Done!

# %%
out # to actually show the video.

# %%
fname = "SuddenHeadChange1D"

anim.save(fname + '.mp4', fps=10, extra_args=['-vcodec', 'libx264'], bitrate=1000)
print(anim.save_count, " frames saved.")
# Out:
# 110  frames saved.

# %%
# !ffmpeg -i SuddenHeadChange1D.mp4 -y SuddenHeadChange1D.gif
# Out:
# ffmpeg version 3.2.1 Copyright (c) 2000-2016 the FFmpeg developers
#   built with llvm-gcc 4.2.1 (LLVM build 2336.11.00)
#   configuration: --prefix=/Volumes/Ramdisk/sw --enable-gpl --enable-pthreads --enable-version3 --enable-libspeex --enable-libvpx --disable-decoder=libvpx --enable-libmp3lame --enable-libtheora --enable-libvorbis --enable-libx264 --enable-avfilter --enable-libopencore_amrwb --enable-libopencore_amrnb --enable-filters --enable-libgsm --enable-libvidstab --enable-libx265 --disable-doc --arch=x86_64 --enable-runtime-cpudetect
#   libavutil      55. 34.100 / 55. 34.100
#   libavcodec     57. 64.101 / 57. 64.101
#   libavformat    57. 56.100 / 57. 56.100
#   libavdevice    57.  1.100 / 57.  1.100
#   libavfilter     6. 65.100 /  6. 65.100
#   libswscale      4.  2.100 /  4.  2.100
#   libswresample   2.  3.100 /  2.  3.100
#   libpostproc    54.  1.100 / 54.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'SuddenHeadChange1D.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.56.100
#   Duration: 00:00:11.00, start: 0.000000, bitrate: 406 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 864x576, 405 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# [swscaler @ 0x7fc3bc9e7000] No accelerated colorspace conversion found from yuv420p to bgr8.
# Output #0, gif, to 'SuddenHeadChange1D.gif':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.56.100
#     Stream #0:0(und): Video: gif, bgr8, 864x576, q=2-31, 200 kb/s, 10 fps, 100 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.64.101 gif
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> gif (native))
# Press [q] to stop, [?] for help
# frame=  110 fps=0.0 q=-0.0 Lsize=     389kB time=00:00:10.91 bitrate= 291.8kbits/s speed=31.5x
# video:387kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.424258%

# %%
pwd
# Out:
# '/Users/Theo/Instituten-Groepen-Overleggen/IHE/git/TransientGroundwaterFlow/excercises_notebooks'

# %%
def ann_dim(x1=None, y1=None, x2=None, y2=None, text="text",
                    astyle0='|-|', astyle1='<->', rotation=0, fc='white', ax=None):
    """Annotate with dimension arrow with centered lavel.
    
    Parameters
    ----------
    x0, y0, x1, y1: 4 floats
        start and end point
    text: str
        the text to use
    astyle0, astyle1 both str
            one of '-', <->', '<-', '->', '<|-', '-|>'
    rotation: float
        text roation in degrees
    fc: str
        face color of background of text label
    ax: Axes obj
        the axes to place the annotation on.
    """
    ax.annotate("", (x1, y1), (x2, y2), textcoords=ax.transData, arrowprops=dict(arrowstyle=astyle0))
    ax.annotate("", (x1, y1), (x2, y2), textcoords=ax.transData, arrowprops=dict(arrowstyle=astyle1))
    ax.text((x1 + x2) / 2, (y1 + y2) / 2, text, ha="center", va="center", bbox=dict(fc=fc, ec='none'))


def ax2fig(x0=None, y0=None, w=None, h=None, ax=None):
    "Convert from data coordinates in ax to figure coordinates"
    fig = ax.figure
    verts = np.array([[x0, y0], [x0 + w, y0 + h]])
    uvD = ax.transData.transform(verts)
    uvF = fig.transFigure.inverted().transform(uvD)
    return uvF[0, 0], uvF[0, 1], uvF[1, 0] - uvF[0, 0], uvF[1, 1] - uvF[0, 1]

class Box(PathPatch):
    """Class Bos as subclass of PathPatch
    
    This has som convenience ability relative to the original PathPatch.
    
    """
    def __init__(self, x0=None, y0=None, w=None, h=None, **kw):
        path = Path(np.array([[0, 0],[w, 0],[w, h],[0, h],[0, 0]]) + np.array([[x0, y0]]), codes=[1, 2, 2, 2, 79])
        #pdb.set_trace()
        #self.x0 = x0
        #self.y0 = y0
        #self.w = w
        #self.h = h
        super().__init__(path, **kw)
        
        
    def update(self, x0=None, y0=None, w=None, h=None):
        """Update the path using one or more of the call parameters.
        
        The parameters not used (None) will be filled-in by the same from self.
        """
        #x0 = x0 if x0 else self.x0
        #y0 = y0 if y0 else self.y0
        #w  = w if w else self.w
        #h  = h if h else self.h
        self.set_path(
            Path(np.array([[0, 0],[w, 0],[w, h],[0, h],[0, 0]]) + np.array([[x0, y0]]),
                 codes=[1, 2, 2, 2, 79])
        )
        
class Arrow(Line2D):
    """Arrow class derive from a Line2D object.
    
    The Idea is to give some more convenience support.
    """
    def __init__(self, x0, y0, w, h, **kw):
        codes = np.ones(6); codes[1:] = 2
        self.path = Path(np.array([[0, 0], [0, h], [-w, h -w], [0, h - 0.75 * w],  [w, h - w], [0, h]]) + np.array([[x0, y0]]), codes)
        xdata, ydata = self.path.vertices.T    
        super().__init__(xdata, ydata, **kw)
  

ax1visible = True
superposition = False

kD, S = 900, 0.10
x0, y0, hb, haq, hac, hLL , hLR, A = 0, 0, 5, 25, 40, 30, 30, 20
w, wL, wR = 200, 100, 100 
   
fig, axs = plt.subplots(2, 1)
fig.set_size_inches(12, 8)
axs[0].set_position((0, 0.4,  1, 0.6))
axs[0].set_frame_on(False)
axs[1].set_position((0, 0.1, 1, 0.2))
axs[1].set_frame_on(False)
axs[0].xaxis.set_visible(False)
axs[1].xaxis.set_visible(False)
axs[0].yaxis.set_visible(False)
axs[1].yaxis.set_visible(False)

axs[1].set_xlim(-5.5 * w, 6.5 * w)
axs[1].set_ylim(-0.5 * haq, 2.5 * haq)

artists = []

for i in range(-7, 7):
    xi = i * w
    fc = "gold" if i==0 else "yellow"
    Bx = Box(x0=xi, y0=y0, w=w, h=haq, fc=fc)
    axs[1].add_patch(Bx)
    artists.append(Bx)
    if i % 2 == 0:
        if i <= 0:
            L = Arrow(xi, y0 + haq, w/30, haq, color='black')
        else:
            L = Arrow(xi, y0 + 2 * haq, -w/30, -haq, color='black')
        axs[1].add_line(L)
    artists.append(L)

basis = Box(x0 - wL, y0, wL + w + wR, -hb, fc='darkgreen')
aquif = Box(x0, y0, w, haq, fc="gold")
aclude = Box(x0, y0 +haq, w, hac, fc="lightgreen")
lakeL = Box(x0 - wL, y0, wL, hLL + A, fc="lightblue")
lakeR = Box(x0 + w , y0, wR, hLR, fc="lightblue")

lakeL2 = Box(x0 - wL, y0, wL, hLL, fc="lightblue")

axs[0].set_xlim((-wL, w + wR))
axs[0].set_ylim((-1.5 * hb, haq + hac + 25))

for thing in [basis, aquif, aclude, lakeL, lakeL2, lakeR]:
    axs[0].add_patch(thing)

ht = haq + hac + hb
axs[0].annotate("", xy=(-wL/2, hLL), xytext=(-wL/2, hLL + A), textcoords=axs[0].transData,
                arrowprops=dict(arrowstyle='<-'))
axs[0].text(-wL/2, hLL + A/2, "A", ha="center", va="center", bbox=dict(fc="lightblue", ec="none"), fontsize=15)

if ax1visible:
    axs[0].annotate("", xy=(0, 0), xytext=(0, haq), textcoords=axs[1].transData,
                    arrowprops=dict(arrowstyle='<->', shrinkA=10, shrinkB=10))
    axs[0].annotate("", xy=(w, 0), xytext=(w, haq), textcoords=axs[1].transData,
                    arrowprops=dict(arrowstyle='<->', shrinkA=10, shrinkB=10))

axs[0].annotate("", xy=(0, ht), xytext=(w, ht), textcoords=axs[0].transData,
                arrowprops=dict(arrowstyle='<->'))
axs[0].annotate("", xy=(0, ht), xytext=(w, ht), textcoords=axs[0].transData,
                arrowprops=dict(arrowstyle='|-|'))
axs[0].text(w/2, ht, "L=200 m", ha="center", va="center", bbox=dict(fc="white", ec="none"), fontsize=20)

axs[0].text(w/2, 0.75 * haq, "kD={:.0f} m2/d, S={:.2f} [0]".format(kD, S), ha="center", va="center", fontsize=20)
axs[0].annotate("x", xy=(0, haq/10), xytext=(w/8, haq/10), textcoords=axs[0].transData,
                arrowprops=dict(arrowstyle='<-'), ha="center", va="center", fontsize=20)
axs[0].annotate("", xy=(0.6 * w, haq/2), xytext=(0.4 * w, haq/2), textcoords=axs[0].transData,
                arrowprops=dict(width=5), ha="center", va="center")


ax = fig.add_axes(ax2fig(0, hLL, w, A, ax=axs[0]), xlim=(0, w), ylim=(0, A))
ax.set_fc("none")
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_frame_on(False)
x = np.linspace(0, 200, 201)

u = lambda t, x: x * np.sqrt(S / (4 * kD * t))

T = 500 * np.sqrt(S /(4 * kD))
n = 8
times = np.hstack((np.array([0.01, 0.1]) * T, np.linspace(0, T, n)[1:]))


if superposition:
    for t in times:
        s = A * erfc(u(t, x))
        for i in range(1, 20):
            s += A * erfc(u(t, x + 2 * i * w))
            s -= A * erfc(u(t, 2 * i * w - x))
        ax.plot(x, s, 'k', lw=0.5)
else:
    for t in times:
        ax.plot(x, A * erfc(u(t, x)), 'k', lw=0.5)

if ax1visible:
    axs[1].set_visible(True)
else:
    axs[1].set_visible(False)

ann_dim(0, 2.5 * haq, w, 2.5 * haq, text="L", fc='w', ax=axs[1])
ann_dim(0, 0.3 * haq, 0.5 * w, 0.3 * haq, text="x", astyle0='-', astyle1='<-', fc='gold', ax=axs[1])
axs[1].text(-0.2 * w, 2 * haq, "A")

axs[1].text(-5 * w, 2.5 * haq, "Superposition scheme", fontsize=15)


def init():
    line.set_data([], [])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-fe8a3a92abfb> in <module>
#      99     xi = i * w
#     100     fc = "gold" if i==0 else "yellow"
# --> 101     Bx = Box(x0=xi, y0=y0, w=w, h=haq, fc=fc)
#     102     axs[1].add_patch(Bx)
#     103     artists.append(Bx)
#
# <ipython-input-29-fe8a3a92abfb> in __init__(self, x0, y0, w, h, **kw)
#      44         #self.w = w
#      45         #self.h = h
# ---> 46         super().__init__(path, **kw)
#      47
#      48
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py in __init__(self, path, **kwargs)
#     989         %(Patch)s
#     990         """
# --> 991         Patch.__init__(self, **kwargs)
#     992         self._path = path
#     993
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      93
#      94         if len(kwargs):
# ---> 95             self.update(kwargs)
#      96
#      97     def get_verts(self):
#
# <ipython-input-29-fe8a3a92abfb> in update(self, x0, y0, w, h)
#      57         #h  = h if h else self.h
#      58         self.set_path(
# ---> 59             Path(np.array([[0, 0],[w, 0],[w, h],[0, h],[0, 0]]) + np.array([[x0, y0]]),
#      60                  codes=[1, 2, 2, 2, 79])
#      61         )
#
# TypeError: unsupported operand type(s) for +: 'int' and 'dict'

# %%
pdb.pm()
# Out:
# reading .pdbrc file in ~/Theo   ... done
# > <ipython-input-27-fe8a3a92abfb>(59)update()
#      57         #h  = h if h else self.h
#      58         self.set_path(
# ---> 59             Path(np.array([[0, 0],[w, 0],[w, h],[0, h],[0, 0]]) + np.array([[x0, y0]]),
#      60                  codes=[1, 2, 2, 2, 79])
#      61         )
#
# ipdb> l
#      54         #x0 = x0 if x0 else self.x0
#      55         #y0 = y0 if y0 else self.y0
#      56         #w  = w if w else self.w
#      57         #h  = h if h else self.h
#      58         self.set_path(
# ---> 59             Path(np.array([[0, 0],[w, 0],[w, h],[0, h],[0, 0]]) + np.array([[x0, y0]]),
#      60                  codes=[1, 2, 2, 2, 79])
#      61         )
#      62
#      63 class Arrow(Line2D):
#      64     """Arrow class derive from a Line2D object.
#
# ipdb> u
# > /Users/Theo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py(95)__init__()
#      93
#      94         if len(kwargs):
# ---> 95             self.update(kwargs)
#      96
#      97     def get_verts(self):
#
# ipdb> kwargs
# {'fc': 'yellow'}
# ipdb> u
# > /Users/Theo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py(991)__init__()
#     989         %(Patch)s
#     990         """
# --> 991         Patch.__init__(self, **kwargs)
#     992         self._path = path
#     993
#
# ipdb> self
# <__main__.Box object at 0x7fd3c9053690>
# ipdb> path
# Path(array([[-1400.,     0.],
#        [-1200.,     0.],
#        [-1200.,    25.],
#        [-1400.,    25.],
#        [-1400.,     0.]]), array([ 1,  2,  2,  2, 79], dtype=uint8))
# ipdb> u
# > <ipython-input-27-fe8a3a92abfb>(46)__init__()
#      44         #self.w = w
#      45         #self.h = h
# ---> 46         super().__init__(path, **kw)
#      47
#      48
#
# ipdb> kw
# {'fc': 'yellow'}
# ipdb> path
# Path(array([[-1400.,     0.],
#        [-1200.,     0.],
#        [-1200.,    25.],
#        [-1400.,    25.],
#        [-1400.,     0.]]), array([ 1,  2,  2,  2, 79], dtype=uint8))
# ipdb> d
# > /Users/Theo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py(991)__init__()
#     989         %(Patch)s
#     990         """
# --> 991         Patch.__init__(self, **kwargs)
#     992         self._path = path
#     993
#
# ipdb>
# > /Users/Theo/opt/anaconda3/lib/python3.7/site-packages/matplotlib/patches.py(95)__init__()
#      93
#      94         if len(kwargs):
# ---> 95             self.update(kwargs)
#      96
#      97     def get_verts(self):
#
# ipdb>
# > <ipython-input-27-fe8a3a92abfb>(59)update()
#      57         #h  = h if h else self.h
#      58         self.set_path(
# ---> 59             Path(np.array([[0, 0],[w, 0],[w, h],[0, h],[0, 0]]) + np.array([[x0, y0]]),
#      60                  codes=[1, 2, 2, 2, 79])
#      61         )
#
# ipdb> n

# %% [markdown]
# # Second case with a strip of length w with boundary conditions on both sides

# %%
ax1visible = True
superposition = True

kD, S = 900, 0.1
x0, y0, hb, haq, hac, hLL , hLR, A, B = 0, 0, 5, 25, 40, 30, 30, 20, 20
w, wL, wR = 200, 100, 100 
 
fig, axs = plt.subplots(2, 1)
fig.set_size_inches(12, 8)
axs[0].set_position((0, 0.4,  1, 0.6))
axs[0].set_frame_on(False)
axs[1].set_position((0, 0.1, 1, 0.2))
axs[1].set_frame_on(False)
axs[0].xaxis.set_visible(False)
axs[1].xaxis.set_visible(False)
axs[0].yaxis.set_visible(False)
axs[1].yaxis.set_visible(False)

axs[1].set_xlim(-5.5 * w, 6.5 * w)
axs[1].set_ylim(-0.5 * haq, 3 * haq)

artists=[]

for i in range(-7, 7):
    xi = i * w
    fc = "gold" if i==0 else "yellow"
    Bx = Box(x0=xi, y0=y0, w=w, h=haq, fc=fc)
    axs[1].add_patch(Bx)
    artists.append(Bx)
    if i % 2 == 0:
        if i <= 0:
            L = Arrow(xi, y0 + haq, w/30, A, color='black')
        else:
            L = Arrow(xi, y0 + haq + A, -w/30, -A, color='black')
        axs[1].add_line(L)
    else:
        if i <= 0:
            L = Arrow(xi, y0 + haq + B, -w/30, -B, color='black')
        else:
            L = Arrow(xi, y0 + haq, w/30, B, color='black')
        axs[1].add_line(L)
    artists.append(L)

basis = Box(x0 - wL, y0, wL + w + wR, -hb, fc='darkgreen')
aquif = Box(x0, y0, w, haq, fc="gold")
aclude = Box(x0, y0 +haq, w, hac, fc="lightgreen")
lakeL = Box(x0 - wL, y0, wL, hLL, fc="lightblue")
lakeR = Box(x0 + w , y0, wR, hLR, fc="lightblue")

lakeL2 = Box(x0 - wL, y0 + hLL, wL, A, fc="lightblue")
lakeR2 = Box(x0 + w, y0 + hLR, wR, B, fc="lightblue")

axs[0].set_xlim((-wL, w + wR))
axs[0].set_ylim((-1.5 * hb, haq + hac + 25))

for thing in [basis, aquif, aclude, lakeL, lakeL2, lakeR, lakeR2]:
    thing.set_visible(True)
    axs[0].add_patch(thing)

ht = haq + hac + hb
axs[0].annotate("", xy=(-wL/2, hLL), xytext=(-wL/2, hLL + A), textcoords=axs[0].transData,
                arrowprops=dict(arrowstyle='<-'))
axs[0].text(-wL/2, hLL + A/2, "A", ha="center", va="center", bbox=dict(fc="lightblue", ec="none"), fontsize=15)

axs[0].annotate("", xy=(w + wR/2, hLR), xytext=(w + wR/2, hLR + B), textcoords=axs[0].transData,
                arrowprops=dict(arrowstyle='<-'))
axs[0].text(w + wR/2, hLR + B/2, "B", ha="center", va="center", bbox=dict(fc="lightblue", ec="none"), fontsize=15)

if ax1visible:
    axs[0].annotate("", xy=(0, 0), xytext=(0, haq), textcoords=axs[1].transData,
                    arrowprops=dict(arrowstyle='<->', shrinkA=10, shrinkB=10))
    axs[0].annotate("", xy=(w, 0), xytext=(w, haq), textcoords=axs[1].transData,
                    arrowprops=dict(arrowstyle='<->', shrinkA=10, shrinkB=10))

axs[0].annotate("", xy=(0, ht), xytext=(w, ht), textcoords=axs[0].transData,
                arrowprops=dict(arrowstyle='<->'))
axs[0].annotate("", xy=(0, ht), xytext=(w, ht), textcoords=axs[0].transData,
                arrowprops=dict(arrowstyle='|-|'))
axs[0].text(w/2, ht, "L=200 m", ha="center", va="center", bbox=dict(fc="white", ec="none"), fontsize=20)

axs[0].text(w/2, 0.75 * haq, "kD={:.0f} m2/d, S={:.2f} [0]".format(kD, S), ha="center", va="center", fontsize=20)
axs[0].annotate("x", xy=(0, haq/10), xytext=(w/8, haq/10), textcoords=axs[0].transData,
                arrowprops=dict(arrowstyle='<-'), ha="center", va="center", fontsize=20)
axs[0].annotate("", xy=(0.6 * w, haq/2), xytext=(0.4 * w, haq/2), textcoords=axs[0].transData,
                arrowprops=dict(width=5), ha="center", va="center")


ax = fig.add_axes(ax2fig(0, hLL, w, A, ax=axs[0]), xlim=(0, w), ylim=(0, A))
ax.set_fc("none")
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_frame_on(False)
x = np.linspace(0, 200, 201)

u = lambda t, x: x * np.sqrt(S / (4 * kD * t))

T = 500 * np.sqrt(S /(4 * kD))
n = 8
times = np.hstack((np.array([0.01, 0.1]) * T, np.linspace(0, T, n)[1:]))


if superposition:
    for t in times:
        s = A * erfc(u(t, x))
        for i in range(1, 20):
            s += A * erfc(u(t, x + 2 * i * w))
            s -= A * erfc(u(t, 2 * i * w - x))
            s -= B * erfc(u(t, x + (2 * i - 1) * w))
            s += B * erfc(u(t, (2 * i - 1) * w - x)) 
        ax.plot(x, s, 'k', lw=0.5)
else:
    for t in times:
        ax.plot(x, A * erfc(u(t, x)), 'k', lw=0.5)

if ax1visible:
    axs[1].set_visible(True)
else:
    axs[1].set_visible(False)

ann_dim(0, 2.5 * haq, w, 2.5 * haq, text="L", fc='w', ax=axs[1])
ann_dim(0, 0.3 * haq, 0.5 * w, 0.3 * haq, text="x", astyle0='-', astyle1='<-', fc='gold', ax=axs[1])
axs[1].text(-0.2 * w, 2 * haq, "A")
axs[1].text(1.1  * w, 2 * haq, "B")

axs[1].text(-5 * w, 2.5 * haq, "Superposition scheme", fontsize=15)
# Out:
# reading .pdbrc file in ~/Theo   ... done
# > <ipython-input-23-e351ed4f1723>(42)__init__()
#      40         path = Path(np.array([[0, 0],[w, 0],[w, h],[0, h],[0, 0]]) + np.array([[x0, y0]]), codes=[1, 2, 2, 2, 79])
#      41         pdb.set_trace()
# ---> 42         super().__init__(path, **kw)
#      43         self.x0 = x0
#      44         self.y0 = y0
#
# ipdb> n
# AttributeError: 'Box' object has no attribute 'y0'
# > <ipython-input-23-e351ed4f1723>(42)__init__()
#      40         path = Path(np.array([[0, 0],[w, 0],[w, h],[0, h],[0, 0]]) + np.array([[x0, y0]]), codes=[1, 2, 2, 2, 79])
#      41         pdb.set_trace()
# ---> 42         super().__init__(path, **kw)
#      43         self.x0 = x0
#      44         self.y0 = y0
#
# ipdb> path
# Path(array([[-1400.,     0.],
#        [-1200.,     0.],
#        [-1200.,    25.],
#        [-1400.,    25.],
#        [-1400.,     0.]]), array([ 1,  2,  2,  2, 79], dtype=uint8))
# ipdb> kw
# {'fc': 'yellow'}
# ipdb> super()
# *** RuntimeError: super(): no arguments
# ipdb> super
# <class 'super'>
# ipdb> q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-24-927c1a7e117e> in <module>
#      25     xi = i * w
#      26     fc = "gold" if i==0 else "yellow"
# ---> 27     Bx = Box(x0=xi, y0=y0, w=w, h=haq, fc=fc)
#      28     axs[1].add_patch(Bx)
#      29     artists.append(Bx)
#
# <ipython-input-23-e351ed4f1723> in __init__(self, x0, y0, w, h, **kw)
#      40         path = Path(np.array([[0, 0],[w, 0],[w, h],[0, h],[0, 0]]) + np.array([[x0, y0]]), codes=[1, 2, 2, 2, 79])
#      41         pdb.set_trace()
# ---> 42         super().__init__(path, **kw)
#      43         self.x0 = x0
#      44         self.y0 = y0
#
# ~/opt/anaconda3/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      92             return self.dispatch_return(frame, arg)
#      93         if event == 'exception':
# ---> 94             return self.dispatch_exception(frame, arg)
#      95         if event == 'c_call':
#      96             return self.trace_dispatch
#
# ~/opt/anaconda3/lib/python3.7/bdb.py in dispatch_exception(self, frame, arg)
#     172                     and arg[0] is StopIteration and arg[2] is None):
#     173                 self.user_exception(frame, arg)
# --> 174                 if self.quitting: raise BdbQuit
#     175         # Stop at the StopIteration or GeneratorExit exception when the user
#     176         # has set stopframe in a generator by issuing a return command, or a
#
# BdbQuit:

# %%
x0
# Out:
# -1400

# %%
aquif.get_path()
# Out:
# Path(array([[1200.,    0.],
#        [1400.,    0.],
#        [1400.,   25.],
#        [1200.,   25.],
#        [1200.,    0.]]), array([ 1,  2,  2,  2, 79], dtype=uint8))
